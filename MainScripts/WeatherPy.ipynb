# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_key
from api_keys import geoapify_key
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 607

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_key}&units=metric"
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | olonets
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | gadzhiyevo
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | tura
# Processing Record 6 of Set 1 | carnarvon
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | keflavik
# Processing Record 9 of Set 1 | west island
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | udachny
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | aykhal
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | buka
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | blackmans bay
# Processing Record 18 of Set 1 | isafjordur
# Processing Record 19 of Set 1 | tomatlan
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | edinburgh of the seven seas
# Processing Record 22 of Set 1 | nar'yan-mar
# Processing Record 23 of Set 1 | olonkinbyen
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | taishan
# Processing Record 26 of Set 1 | bilibino
# Processing Record 27 of Set 1 | dickinson
# Processing Record 28 of Set 1 | nagqu
# Processing Record 29 of Set 1 | praia da vitoria
# Processing Record 30 of Set 1 | al hada
# Processing Record 31 of Set 1 | adamstown
# Processing Record 32 of Set 1 | undurkhaan
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | utrik
# Processing Record 35 of Set 1 | invercargill
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | juneau
# Processing Record 38 of Set 1 | port mathurin
# Processing Record 39 of Set 1 | waitangi
# Processing Record 40 of Set 1 | lihue
# Processing Record 41 of Set 1 | mount pearl
# Processing Record 42 of Set 1 | lata
# Processing Record 43 of Set 1 | sola
# Processing Record 44 of Set 1 | gardnerville ranchos
# Processing Record 45 of Set 1 | sitka
# Processing Record 46 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 47 of Set 1 | pibor
# City not found. Skipping...
# Processing Record 48 of Set 1 | coquimbo
# Processing Record 49 of Set 1 | papatowai
# Processing Record 50 of Set 1 | la passe
# Processing Record 0 of Set 2 | enewetak
# Processing Record 1 of Set 2 | khanty-mansiysk
# Processing Record 2 of Set 2 | college
# Processing Record 3 of Set 2 | puerto baquerizo moreno
# Processing Record 4 of Set 2 | quiberon
# Processing Record 5 of Set 2 | yulinshi
# Processing Record 6 of Set 2 | hotan
# Processing Record 7 of Set 2 | kendari
# Processing Record 8 of Set 2 | portland
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | camana
# Processing Record 11 of Set 2 | kingston
# Processing Record 12 of Set 2 | wailua homesteads
# Processing Record 13 of Set 2 | puerto natales
# Processing Record 14 of Set 2 | colon
# Processing Record 15 of Set 2 | am timan
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | karratha
# Processing Record 18 of Set 2 | along
# Processing Record 19 of Set 2 | chernyshevskiy
# Processing Record 20 of Set 2 | nikolayevsk-on-amure
# Processing Record 21 of Set 2 | micheweni
# Processing Record 22 of Set 2 | abeche
# Processing Record 23 of Set 2 | stanley
# Processing Record 24 of Set 2 | vilyuysk
# Processing Record 25 of Set 2 | lompoc
# Processing Record 26 of Set 2 | qaqortoq
# Processing Record 27 of Set 2 | pathein
# Processing Record 28 of Set 2 | ke-macina
# Processing Record 29 of Set 2 | capayan
# Processing Record 30 of Set 2 | dois vizinhos
# Processing Record 31 of Set 2 | masaka
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | aranda de duero
# Processing Record 34 of Set 2 | felege neway
# Processing Record 35 of Set 2 | newman
# Processing Record 36 of Set 2 | port macquarie
# Processing Record 37 of Set 2 | dudinka
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | georgetown
# Processing Record 40 of Set 2 | vila vicosa
# Processing Record 41 of Set 2 | aripuana
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | zaysan
# Processing Record 44 of Set 2 | mana
# Processing Record 45 of Set 2 | urucara
# Processing Record 46 of Set 2 | chilliwack
# Processing Record 47 of Set 2 | kiunga
# Processing Record 48 of Set 2 | pekalongan
# Processing Record 49 of Set 2 | brooks
# Processing Record 0 of Set 3 | atafu village
# Processing Record 1 of Set 3 | usogorsk
# Processing Record 2 of Set 3 | aadorf
# Processing Record 3 of Set 3 | hamilton
# Processing Record 4 of Set 3 | okhotsk
# Processing Record 5 of Set 3 | hawaiian paradise park
# Processing Record 6 of Set 3 | huntsville
# Processing Record 7 of Set 3 | kotel'nikovo
# Processing Record 8 of Set 3 | cheremukhovo
# Processing Record 9 of Set 3 | aasiaat
# Processing Record 10 of Set 3 | serowe
# Processing Record 11 of Set 3 | barra dos coqueiros
# Processing Record 12 of Set 3 | afaahiti
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | winnemucca
# Processing Record 15 of Set 3 | sao gabriel da cachoeira
# Processing Record 16 of Set 3 | jiuquan
# Processing Record 17 of Set 3 | moose jaw
# Processing Record 18 of Set 3 | scarborough
# Processing Record 19 of Set 3 | kupang
# Processing Record 20 of Set 3 | midvagur
# Processing Record 21 of Set 3 | torremaggiore
# Processing Record 22 of Set 3 | longyearbyen
# Processing Record 23 of Set 3 | monrovia
# Processing Record 24 of Set 3 | bhadasar
# Processing Record 25 of Set 3 | bel ombre
# Processing Record 26 of Set 3 | salinopolis
# Processing Record 27 of Set 3 | salalah
# Processing Record 28 of Set 3 | whitehorse
# Processing Record 29 of Set 3 | ocozocoautla de espinosa
# Processing Record 30 of Set 3 | freetown
# Processing Record 31 of Set 3 | comodoro rivadavia
# Processing Record 32 of Set 3 | iquique
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | bamboo flat
# Processing Record 36 of Set 3 | uturoa
# Processing Record 37 of Set 3 | fauske
# Processing Record 38 of Set 3 | chibougamau
# Processing Record 39 of Set 3 | tangalle
# Processing Record 40 of Set 3 | zouerate
# Processing Record 41 of Set 3 | boali
# Processing Record 42 of Set 3 | bukama
# Processing Record 43 of Set 3 | punta arenas
# Processing Record 44 of Set 3 | walvis bay
# Processing Record 45 of Set 3 | saipan
# Processing Record 46 of Set 3 | darwin
# Processing Record 47 of Set 3 | sao felix do xingu
# Processing Record 48 of Set 3 | flen
# Processing Record 49 of Set 3 | thompson
# Processing Record 0 of Set 4 | parnamirim
# Processing Record 1 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 2 of Set 4 | spring creek
# Processing Record 3 of Set 4 | emkhomazi
# Processing Record 4 of Set 4 | san juan de abajo
# Processing Record 5 of Set 4 | richards bay
# Processing Record 6 of Set 4 | toktogul
# Processing Record 7 of Set 4 | mahanoro
# Processing Record 8 of Set 4 | shaowu
# Processing Record 9 of Set 4 | las palmas
# Processing Record 10 of Set 4 | vila velha
# Processing Record 11 of Set 4 | chonchi
# Processing Record 12 of Set 4 | saynshand
# Processing Record 13 of Set 4 | trairi
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | smithers
# Processing Record 16 of Set 4 | arteche
# Processing Record 17 of Set 4 | tual
# Processing Record 18 of Set 4 | muroto-misakicho
# Processing Record 19 of Set 4 | timbuktu
# Processing Record 20 of Set 4 | ola
# Processing Record 21 of Set 4 | hammerfest
# Processing Record 22 of Set 4 | ishigaki
# Processing Record 23 of Set 4 | isla vista
# Processing Record 24 of Set 4 | port douglas
# Processing Record 25 of Set 4 | mil'kovo
# Processing Record 26 of Set 4 | sonsorol village
# City not found. Skipping...
# Processing Record 27 of Set 4 | phek
# Processing Record 28 of Set 4 | tazovsky
# Processing Record 29 of Set 4 | kerikeri
# Processing Record 30 of Set 4 | labrador city
# Processing Record 31 of Set 4 | belomorsk
# Processing Record 32 of Set 4 | dul'durga
# Processing Record 33 of Set 4 | oulad teima
# Processing Record 34 of Set 4 | cochrane
# Processing Record 35 of Set 4 | bredasdorp
# Processing Record 36 of Set 4 | ulladulla
# Processing Record 37 of Set 4 | dame-marie
# Processing Record 38 of Set 4 | changling
# Processing Record 39 of Set 4 | howard springs
# Processing Record 40 of Set 4 | san jose village
# City not found. Skipping...
# Processing Record 41 of Set 4 | pleiku
# Processing Record 42 of Set 4 | vadso
# Processing Record 43 of Set 4 | clarion
# Processing Record 44 of Set 4 | elektrenai
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | pizarro
# Processing Record 47 of Set 4 | ilulissat
# Processing Record 48 of Set 4 | nema
# Processing Record 49 of Set 4 | laguna
# Processing Record 0 of Set 5 | hasaki
# Processing Record 1 of Set 5 | vredendal
# Processing Record 2 of Set 5 | raduzhnyy
# Processing Record 3 of Set 5 | nagtipunan
# Processing Record 4 of Set 5 | ambon
# Processing Record 5 of Set 5 | graaff-reinet
# Processing Record 6 of Set 5 | itaituba
# Processing Record 7 of Set 5 | calvinia
# Processing Record 8 of Set 5 | kavaratti
# Processing Record 9 of Set 5 | changzhi
# Processing Record 10 of Set 5 | port lincoln
# Processing Record 11 of Set 5 | guanica
# Processing Record 12 of Set 5 | san julian
# Processing Record 13 of Set 5 | harstad
# Processing Record 14 of Set 5 | rongelap
# Processing Record 15 of Set 5 | san andres
# Processing Record 16 of Set 5 | polyarnyy
# Processing Record 17 of Set 5 | hovd
# Processing Record 18 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 19 of Set 5 | talnakh
# Processing Record 20 of Set 5 | novodvinsk
# Processing Record 21 of Set 5 | vorgashor
# Processing Record 22 of Set 5 | machico
# Processing Record 23 of Set 5 | amurzet
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | jalai nur
# Processing Record 26 of Set 5 | sheridan
# Processing Record 27 of Set 5 | larroque
# Processing Record 28 of Set 5 | pariaman
# Processing Record 29 of Set 5 | alice springs
# Processing Record 30 of Set 5 | tralee
# Processing Record 31 of Set 5 | sisimiut
# Processing Record 32 of Set 5 | murzuq
# Processing Record 33 of Set 5 | santa marta de ortigueira
# Processing Record 34 of Set 5 | mount isa
# Processing Record 35 of Set 5 | impfondo
# Processing Record 36 of Set 5 | san patricio
# Processing Record 37 of Set 5 | la sarre
# Processing Record 38 of Set 5 | abbeville
# Processing Record 39 of Set 5 | yeppoon
# Processing Record 40 of Set 5 | ust-nera
# Processing Record 41 of Set 5 | pitt meadows
# Processing Record 42 of Set 5 | dera bugti
# Processing Record 43 of Set 5 | ancud
# Processing Record 44 of Set 5 | badger
# Processing Record 45 of Set 5 | libog
# Processing Record 46 of Set 5 | sechura
# Processing Record 47 of Set 5 | nizhnesortymskiy
# Processing Record 48 of Set 5 | bazar-korgon
# Processing Record 49 of Set 5 | horta
# Processing Record 0 of Set 6 | fada
# Processing Record 1 of Set 6 | antsiranana
# Processing Record 2 of Set 6 | bandarbeyla
# Processing Record 3 of Set 6 | flying fish cove
# Processing Record 4 of Set 6 | kaliganj
# Processing Record 5 of Set 6 | chiili
# City not found. Skipping...
# Processing Record 6 of Set 6 | st. john's
# Processing Record 7 of Set 6 | arsin
# Processing Record 8 of Set 6 | victoria point
# Processing Record 9 of Set 6 | avarua
# Processing Record 10 of Set 6 | majene
# Processing Record 11 of Set 6 | fortuna
# Processing Record 12 of Set 6 | castillos
# Processing Record 13 of Set 6 | east london
# Processing Record 14 of Set 6 | susuman
# Processing Record 15 of Set 6 | kristiansund
# Processing Record 16 of Set 6 | labytnangi
# Processing Record 17 of Set 6 | jaicos
# Processing Record 18 of Set 6 | tolanaro
# Processing Record 19 of Set 6 | island harbour
# Processing Record 20 of Set 6 | mpigi
# Processing Record 21 of Set 6 | nadym
# Processing Record 22 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 23 of Set 6 | iskateley
# Processing Record 24 of Set 6 | al 'amarah
# Processing Record 25 of Set 6 | antofagasta
# Processing Record 26 of Set 6 | camiri
# Processing Record 27 of Set 6 | mirzapur
# Processing Record 28 of Set 6 | ongjin
# Processing Record 29 of Set 6 | haiku-pauwela
# Processing Record 30 of Set 6 | zadar
# Processing Record 31 of Set 6 | puerto penasco
# Processing Record 32 of Set 6 | simanggang
# Processing Record 33 of Set 6 | dwarka
# Processing Record 34 of Set 6 | peniche
# Processing Record 35 of Set 6 | sao tome
# Processing Record 36 of Set 6 | khovd
# Processing Record 37 of Set 6 | nemuro
# Processing Record 38 of Set 6 | heves
# Processing Record 39 of Set 6 | tazacorte
# Processing Record 40 of Set 6 | margaret river
# Processing Record 41 of Set 6 | malvan
# Processing Record 42 of Set 6 | yarmouth
# Processing Record 43 of Set 6 | ngaruawahia
# Processing Record 44 of Set 6 | goure
# Processing Record 45 of Set 6 | launceston
# Processing Record 46 of Set 6 | amos
# Processing Record 47 of Set 6 | aswan
# Processing Record 48 of Set 6 | ridder
# Processing Record 49 of Set 6 | kulia village
# City not found. Skipping...
# Processing Record 0 of Set 7 | gornopravdinsk
# Processing Record 1 of Set 7 | fort bragg
# Processing Record 2 of Set 7 | simi valley
# Processing Record 3 of Set 7 | san paolo
# Processing Record 4 of Set 7 | taulaga
# Processing Record 5 of Set 7 | opuwo
# Processing Record 6 of Set 7 | gizo
# Processing Record 7 of Set 7 | vohipaho
# City not found. Skipping...
# Processing Record 8 of Set 7 | granada
# Processing Record 47 of Set 9 | port shepstone
# Processing Record 48 of Set 9 | sao joao da barra
# Processing Record 49 of Set 9 | hadibu
# Processing Record 0 of Set 10 | vytegra
# Processing Record 1 of Set 10 | faya-largeau
# Processing Record 2 of Set 10 | kindu
# Processing Record 3 of Set 10 | chigorodo
# Processing Record 4 of Set 10 | kodinar
# Processing Record 5 of Set 10 | kievka
# Processing Record 6 of Set 10 | kenora
# Processing Record 7 of Set 10 | pagar alam
# Processing Record 8 of Set 10 | eichendorf
# Processing Record 9 of Set 10 | narrabri
# Processing Record 10 of Set 10 | nuuk
# Processing Record 11 of Set 10 | maumere
# Processing Record 12 of Set 10 | minas de marcona
# Processing Record 13 of Set 10 | lisala
# Processing Record 14 of Set 10 | kone
# Processing Record 15 of Set 10 | yangor
# City not found. Skipping...
# Processing Record 16 of Set 10 | saint croix
# Processing Record 17 of Set 10 | khawr fakkan
# Processing Record 18 of Set 10 | turpan
# Processing Record 19 of Set 10 | pisco
# Processing Record 20 of Set 10 | anna regina
# Processing Record 21 of Set 10 | al jawf
# Processing Record 22 of Set 10 | yumaguzino
# Processing Record 23 of Set 10 | kirensk
# Processing Record 24 of Set 10 | mont-laurier
# Processing Record 25 of Set 10 | sandnessjoen
# Processing Record 26 of Set 10 | nogliki
# Processing Record 27 of Set 10 | christchurch
# Processing Record 28 of Set 10 | mitu
# Processing Record 29 of Set 10 | gargalianoi
# Processing Record 30 of Set 10 | heroica caborca
# Processing Record 31 of Set 10 | rio guayabal de yateras
# Processing Record 32 of Set 10 | dalandzadgad
# Processing Record 33 of Set 10 | sidney
# Processing Record 34 of Set 10 | tsiombe
# Processing Record 35 of Set 10 | zandvoort
# Processing Record 36 of Set 10 | nyurba
# Processing Record 37 of Set 10 | belmonte
# Processing Record 38 of Set 10 | kayangel
# Processing Record 39 of Set 10 | kruisfontein
# Processing Record 40 of Set 10 | leava
# Processing Record 41 of Set 10 | bandon
# Processing Record 42 of Set 10 | hinton
# Processing Record 43 of Set 10 | gaspe
# Processing Record 44 of Set 10 | san antonio de pale
# Processing Record 45 of Set 10 | marco island
# Processing Record 46 of Set 10 | hirara
# Processing Record 47 of Set 10 | pyhajarvi
# Processing Record 48 of Set 10 | nurlat
# Processing Record 49 of Set 10 | deir ez-zor
# Processing Record 0 of Set 11 | taroa
# Processing Record 1 of Set 11 | kolokani
# Processing Record 2 of Set 11 | fletcher
# Processing Record 3 of Set 11 | yanam
# Processing Record 4 of Set 11 | lagoa
# Processing Record 5 of Set 11 | auki
# Processing Record 6 of Set 11 | arroyo de la luz
# Processing Record 7 of Set 11 | barra do bugres
# Processing Record 8 of Set 11 | fisterra
# Processing Record 9 of Set 11 | prince rupert
# Processing Record 10 of Set 11 | borrazopolis
# Processing Record 11 of Set 11 | cannonvale
# Processing Record 12 of Set 11 | tyukhtet
# Processing Record 13 of Set 11 | sinop
# Processing Record 14 of Set 11 | axim
# Processing Record 15 of Set 11 | akureyri
# Processing Record 16 of Set 11 | alvaraes
# Processing Record 17 of Set 11 | la ronge
# Processing Record 18 of Set 11 | mananjary
# Processing Record 19 of Set 11 | parabel'
# Processing Record 20 of Set 11 | miri
# Processing Record 21 of Set 11 | luza
# Processing Record 22 of Set 11 | palmer
# Processing Record 23 of Set 11 | anloga
# Processing Record 24 of Set 11 | peace river
# Processing Record 25 of Set 11 | saguday
# Processing Record 26 of Set 11 | katsuren-haebaru
# Processing Record 27 of Set 11 | bengbu
# Processing Record 28 of Set 11 | swift current
# Processing Record 29 of Set 11 | galliano
# Processing Record 30 of Set 11 | assab
# Processing Record 31 of Set 11 | siguiri
# Processing Record 32 of Set 11 | semirara
# Processing Record 33 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 34 of Set 11 | bua yai
# Processing Record 35 of Set 11 | sydney mines
# Processing Record 36 of Set 11 | turuntayevo
# Processing Record 37 of Set 11 | saguenay
# Processing Record 38 of Set 11 | shajiang
# Processing Record 39 of Set 11 | quellon
# Processing Record 40 of Set 11 | katsina
# Processing Record 41 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 42 of Set 11 | as sulayyil
# Processing Record 43 of Set 11 | poxoreo
# Processing Record 44 of Set 11 | ust'-ilimsk
# Processing Record 45 of Set 11 | mpika
# Processing Record 46 of Set 11 | amahai
# Processing Record 47 of Set 11 | cockburn town
# Processing Record 48 of Set 11 | phongsali
# Processing Record 49 of Set 11 | hami
# Processing Record 0 of Set 12 | seogwipo
# City not found. Skipping...
# Processing Record 1 of Set 12 | batu pahat
# Processing Record 2 of Set 12 | padegan-e manjil
# City not found. Skipping...
# Processing Record 3 of Set 12 | berezovo
# Processing Record 4 of Set 12 | taoudenni
# Processing Record 5 of Set 12 | ban houayxay
# Processing Record 6 of Set 12 | remire-montjoly
# Processing Record 7 of Set 12 | qacha's nek
# Processing Record 8 of Set 12 | castelli
# Processing Record 9 of Set 12 | bonthe
# Processing Record 10 of Set 12 | okahao
# Processing Record 11 of Set 12 | santa rosalia
# Processing Record 12 of Set 12 | dehui
# Processing Record 13 of Set 12 | bezhetsk
# Processing Record 14 of Set 12 | codrington
# Processing Record 15 of Set 12 | kiama
# Processing Record 16 of Set 12 | tympaki
# Processing Record 17 of Set 12 | nyrob
# Processing Record 18 of Set 12 | hede
# Processing Record 19 of Set 12 | fort stockton
# Processing Record 20 of Set 12 | saint-leu
# Processing Record 21 of Set 12 | vargashi
# Processing Record 22 of Set 12 | saldanha
# Processing Record 23 of Set 12 | jinxiang
# Processing Record 24 of Set 12 | kapuskasing
# Processing Record 25 of Set 12 | ivdel'
# Processing Record 26 of Set 12 | sirte
# Processing Record 27 of Set 12 | egilsstadir
# Processing Record 28 of Set 12 | pangkalanbuun
# Processing Record 29 of Set 12 | la'ie
# Processing Record 30 of Set 12 | selfoss
# Processing Record 31 of Set 12 | pico truncado
# Processing Record 32 of Set 12 | utete
# Processing Record 33 of Set 12 | rikaze
# Processing Record 34 of Set 12 | kembe
# Processing Record 35 of Set 12 | amga
# Processing Record 36 of Set 12 | tofol
# Processing Record 37 of Set 12 | an nuhud
# Processing Record 38 of Set 12 | selsey
# Processing Record 39 of Set 12 | pitimbu
# Processing Record 40 of Set 12 | luquillo
# Processing Record 41 of Set 12 | slave lake
# Processing Record 42 of Set 12 | greymouth
# Processing Record 43 of Set 12 | nova vicosa
# Processing Record 44 of Set 12 | awjilah
# Processing Record 45 of Set 12 | chegdomyn
# Processing Record 46 of Set 12 | jiazi
# Processing Record 47 of Set 12 | forio
# Processing Record 48 of Set 12 | kamina
# Processing Record 49 of Set 12 | kudahuvadhoo
# Processing Record 0 of Set 13 | jutai
# Processing Record 1 of Set 13 | totskoye
# Processing Record 2 of Set 13 | rovaniemi
# Processing Record 3 of Set 13 | kuraymah
# Processing Record 4 of Set 13 | holualoa
# Processing Record 5 of Set 13 | crane
# Processing Record 6 of Set 13 | zastron
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          585
# Lat           585
# Lng           585
# Max Temp      585
# Humidity      585
# Cloudiness    585
# Wind Speed    585
# Country       585
# Date          585
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         olonets  60.9847  32.9698     12.03        87           4
# 1          bethel  41.3712 -73.4140     26.62        78          97
# 2      gadzhiyevo  69.2551  33.3362      9.79        79         100
# 3  ribeira grande  38.5167 -28.7000     22.65        87          67
# 4            tura  25.5198  90.2201     25.39        96         100
#
#    Wind Speed Country        Date
# 0        2.00      RU  1720575089
# 1        1.46      US  1720575090
# 2        3.09      RU  1720575092
# 3        0.45      PT  1720575093
# 4        3.52      IN  1720575095

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               olonets  60.9847  32.9698     12.03        87           4
# 1                bethel  41.3712 -73.4140     26.62        78          97
# 2            gadzhiyevo  69.2551  33.3362      9.79        79         100
# 3        ribeira grande  38.5167 -28.7000     22.65        87          67
# 4                  tura  25.5198  90.2201     25.39        96         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.00      RU  1720575089
# 1              1.46      US  1720575090
# 2              3.09      RU  1720575092
# 3              0.45      PT  1720575093
# 4              3.52      IN  1720575095

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Latitude vs. Max Temperature (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regress_plots(x, y):
    x_values = x
    y_values = y
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f"The r-squared is: {rvalue**2}")
    return line_eq

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0), :]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               olonets  60.9847  32.9698     12.03        87           4
# 1                bethel  41.3712 -73.4140     26.62        78          97
# 2            gadzhiyevo  69.2551  33.3362      9.79        79         100
# 3        ribeira grande  38.5167 -28.7000     22.65        87          67
# 4                  tura  25.5198  90.2201     25.39        96         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.00      RU  1720575089
# 1              1.46      US  1720575090
# 2              3.09      RU  1720575092
# 3              0.45      PT  1720575093
# 4              3.52      IN  1720575095

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0), :]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 5           carnarvon -24.8667  113.6333     22.13        81          21
# 6             ushuaia -54.8000  -68.3000      3.81        75          40
# 8         west island -12.1568   96.8225     27.99        89          20
# 9           grytviken -54.2811  -36.5092     -1.23        91          99
# 11       puerto ayora  -0.7393  -90.3518     20.86       100          50
#
#          Wind Speed Country        Date
# City_ID
# 5              5.81      AU  1720575096
# 6             16.46      AR  1720575097
# 8              2.57      CC  1720575100
# 9              5.70      GS  1720575101
# 11             3.24      EC  1720575104

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
equation = regress_plots(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(equation,(0,280),fontsize=15,color="red")
plt.title("Latitude vs Max Temp")
plt.show()
# Out:
# The r-squared is: 0.3117868810578696

# %%
# Linear regression on Southern Hemisphere
equation = regress_plots(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(equation,(-30,0),fontsize=15,color="red")
plt.title("Latitude vs Max Temp")
plt.show()
# Out:
# The r-squared is: 0.5822811360869931

# %% [markdown]
# **Discussion about the linear relationship:** In the above linear regression plots, the latitudes of the cities were paired towards that city's max temperature in Celsius. The plots depict the latitudes in the northern hemisphere and southern hemisphere respectively. The northern hemisphere has an r^2 value of approximately 0.31, which means that 31% of the temperatures experienced by these northern hemisphere cities could be attributed to their latitude. On the other hand, the southern hemisphere had an r^2 value of approximately 0.58, which means that 58%  of the temperatures experienced by these southern hemisphere cities could be attributed to their latitude. It would appear that the latitude in the southern hemisphere has a stronger correlation than it does in the northern hemisphere. Given that there is more landmass in the northern hemisphere, which could possibly allow for more variation in climate between cities, it would make sense that the latitude would have a weaker correlation than in the southern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
equation = regress_plots(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(equation,(50,10),fontsize=15,color="red")
plt.title("Latitude vs Humidity")
plt.show()
# Out:
# The r-squared is: 0.00820039654596859

# %%
# Southern Hemisphere
equation = regress_plots(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(equation,(-50,30),fontsize=15,color="red")
plt.title("Latitude vs Humidity")
plt.show()
# Out:
# The r-squared is: 0.0006835628500546242

# %% [markdown]
# **Discussion about the linear relationship:** The regression plot depicting latitude versus humidity within the northern hemisphere has an r^2 value of approximately 0.0082, while the regresison plot for the southern hemisphere has an r^2 value of approximately 0.00069. While the northern hemisphere has a larger r^2 value than the souther hemisphere cities, the difference is negligible. At the same time, the r^2 values are so small that we can conclude that latitude has no correlation on the humidity that these cities experience.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
equation = regress_plots(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(equation,(40,10),fontsize=15,color="red")
plt.title("Latitude vs Cloudiness")
plt.show()
# Out:
# The r-squared is: 0.019178873641388323

# %%
# Southern Hemisphere
equation = regress_plots(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(equation,(-30,30),fontsize=15,color="red")
plt.title("Latitude vs Cloudiness")
plt.show()
# Out:
# The r-squared is: 0.00834595674824848

# %% [markdown]
# **Discussion about the linear relationship:** Similar to the latitude versus humidity regression plots, the r^2 value of the northern hemisphere plot is negligibly larger than the southern hemisphere plot. The r^2 values are also so small that we can conclude that latitude has no correlation on the cloudiness that these cities experience.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
regress_plots(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(equation,(10,11),fontsize=15,color="red")
plt.title("Latitude vs Wind Speed")
plt.show()
# Out:
# The r-squared is: 0.006593700290114767

# %%
# Southern Hemisphere
equation = regress_plots(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(equation,(-50,11),fontsize=15,color="red")
plt.title("Latitude vs Wind Speed")
plt.show()
# Out:
# The r-squared is: 0.05953189494812593

# %% [markdown]
# **Discussion about the linear relationship:** In the regression plots of latitude versus wind speed for the northern and southern hemisphere cities, the r^2 values found were both very small that we can conclude that latitude has no correlation to wind speed.
